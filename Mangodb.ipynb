# %%
import streamlit as st

# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://Marii:Password@cluster0.okcsmig.mongodb.net/?retryWrites=true&w=majority"
uri1 = "mongodb://localhost:27017"

# Create a new client and connect to the server
client = MongoClient(uri1, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
    
db = client.youtubedb
records = db.Channel
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
print([x['_id'] for x in records.find({"_id":{'$ne':2}})])
# Out:
# ['UC1VT8SUJ7yvIkE4eCzXVSNA', 'UC7LW0lREbuLEdGw37V4w7rQ', 'UCNb8hHMKUSL4HigPdg2ht4A', 'UCi8cCe02oSGS21lHrAcjogA', 'UCjC8sqwzUme0LDJ2CeCx2Rw', 'UCwVEhEzsjLym_u1he4XWFkg']

# %%
dd = records.find({}, {"_id": True, })
print([x['_id'] for x in dd])
# Out:
# ['UCjC8sqwzUme0LDJ2CeCx2Rw', 'UCi8cCe02oSGS21lHrAcjogA', 'UCwVEhEzsjLym_u1he4XWFkg', 'UC1VT8SUJ7yvIkE4eCzXVSNA', 'UCNb8hHMKUSL4HigPdg2ht4A', 'UC7LW0lREbuLEdGw37V4w7rQ']

# %%
ls = [x['_id'] for x in records.find({"_id":{'$ne':2}})]
st.dataframe({'Channel List':ls})
# Out:
# DeltaGenerator()

# %%
# Out:
#   File "C:\Users\HP\AppData\Local\Temp\ipykernel_2952\3487965399.py", line 1
#     streamlit run C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py
#               ^
# SyntaxError: invalid syntax

# %%
sqldata = tuple([int(x) if x.isnumeric() else x for x in channel['data'].values()])
sqldata
# Out:
# ('UCi8cCe02oSGS21lHrAcjogA', 'Abishek Kumar', 927000, 267888037, 104)

# %%
insert_query
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14068\3795183631.py in <module>
# ----> 1 insert_query
#
# NameError: name 'insert_query' is not defined

# %%
from PIL import Image
import io

im = Image.open("image1.png")

image_bytes = io.BytesIO()
im.save(image_bytes, format='PNG')

dict1 = {
"_id":"nirmalguvi",
'image': image_bytes.getvalue()
}

records.insert_one(dict1)

# %%
#Reading image from Mongo
#from pymongo import MongoClient
from PIL import Image
import io
#import matplotlib.pyplot as plt


retrival = records.find_one({"_id":"nirmalguvi"})
#print(retrival)


pil_img = Image.open(io.BytesIO(retrival['image']))
#plt.imshow(pil_img)
#pil_img.show()
pil_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=220x165>
