# %%
from pymongo.mongo_client import MongoClient
from pymongo.server_api import ServerApi

uri = "mongodb+srv://Marii:Password@cluster0.okcsmig.mongodb.net/?retryWrites=true&w=majority"

# Create a new client and connect to the server
client = MongoClient(uri, server_api=ServerApi('1'))

# Send a ping to confirm a successful connection
try:
    client.admin.command('ping')
    print("Pinged your deployment. You successfully connected to MongoDB!")
except Exception as e:
    print(e)
    
db = client.youtubedb
records = db.Channel
# Out:
# Pinged your deployment. You successfully connected to MongoDB!

# %%
channel = records.find_one({"_id": "UC1VT8SUJ7yvIkE4eCzXVSNA"})
print(channel)
# Out:
# None

# %%
for x in records.find():
    print(x)
# Out:
# {'_id': 'UCjC8sqwzUme0LDJ2CeCx2Rw', 'data': {'ChanneID': 'UCjC8sqwzUme0LDJ2CeCx2Rw', 'channel_name': 'Guna shanmuga', 'SubscriberCount': '123000', 'ViewCount': '2968803', 'VideoCount': '91'}, 'Playlist': {'Playlist_id': ['PLsz9fU0IH_hIEIr4wunFZO5z-nsyG92sS', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44'], 'ChannelID': ['UCjC8sqwzUme0LDJ2CeCx2Rw', 'UCjC8sqwzUme0LDJ2CeCx2Rw'], 'Playlist_name': ['Guna Shanmuga Interview', 'FOREX BEGINNER AND INTERMEDIATE FULL COURSE!']}, 'Video_details': {'Video_id': ['87XPSx-167U', 'cok9JyY2zR0', 'A5F8b0HVmBU', '5I-NkMXP-0U', 'lpAePJBF8Vs', '25xgTP8OHIU', '2mWxUbqZK1w', 'Bxghci_VGR8', 'QYWGelxUOxQ', 'za2QI7dcvOA', 'gXjI3Nymbcs', 'ei7ZdnK_vfk', 'rZDzgwl6cEs', 'IE1rAPbEsSE', 'lpAePJBF8Vs', '25xgTP8OHIU', '2mWxUbqZK1w', 'Bxghci_VGR8', 'QYWGelxUOxQ', 'za2QI7dcvOA', 'gXjI3Nymbcs', 'ei7ZdnK_vfk', 'rZDzgwl6cEs', 'IE1rAPbEsSE', '5WhfOcH2ZKc', 'NZHbV67wHcw', 'Q0xW5POI-rU', 'hNT4NFTBxMk', 'HwpAv1qh3eE', 'Zho1fh_2TQk', 'iQvXS4MWkmw', 'Ow0uWLUQsog', 'gzI6noHosYQ', 'cuI7uLyj72E', 'lpAePJBF8Vs', '25xgTP8OHIU', '2mWxUbqZK1w', 'Bxghci_VGR8', 'QYWGelxUOxQ', 'za2QI7dcvOA', 'gXjI3Nymbcs', 'ei7ZdnK_vfk', 'rZDzgwl6cEs', 'IE1rAPbEsSE', '5WhfOcH2ZKc', 'NZHbV67wHcw', 'Q0xW5POI-rU', 'hNT4NFTBxMk', 'HwpAv1qh3eE', 'Zho1fh_2TQk', 'iQvXS4MWkmw', 'Ow0uWLUQsog', 'gzI6noHosYQ', 'cuI7uLyj72E', 'VNxcxHDbJ5A', 'QJOxH2VQr0w', '3p19fpIK3Yo', 'Q2kiKKvurZk', 'FjkJVIrkWgk'], 'Playlist_id': ['PLsz9fU0IH_hIEIr4wunFZO5z-nsyG92sS', 'PLsz9fU0IH_hIEIr4wunFZO5z-nsyG92sS', 'PLsz9fU0IH_hIEIr4wunFZO5z-nsyG92sS', 'PLsz9fU0IH_hIEIr4wunFZO5z-nsyG92sS', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44', 'PLsz9fU0IH_hIAQsOBOsgIBurTfXKe7q44'], 'Video_name': ['22 வயதில் கோடிகளில் Business  $1000 to $240 M ஆன கதை | FOREX TRADING GUNA SHANMUGA INSPIRING பேட்டி', "TRADING ரகசியங்களை உடைத்தெறிந்த GUNA 'சம்பாரிச்ச காசை குட்டிப்போட வைக்கும் IDEA!'", 'Trading-ம் சொல்லிக்கொடுத்து கோடிகளில் சம்பாதிக்க பணமும் கொடுக்கும் 22 வயது\xa0இளைஞன்! INSPIRING\xa0பேட்டி', 'கோடிகளில் பணம் சம்பாதிப்பது இவ்வளவு ஈஸியா? - கு ...

# %%
channel

# %%
sqldata = tuple([int(x) if x.isnumeric() else x for x in channel['data'].values()])
sqldata
# Out:
# ('UCi8cCe02oSGS21lHrAcjogA', 'Abishek Kumar', 927000, 267888037, 104)

# %%
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14068\4072797727.py in <module>
# ----> 1 rows = [(data1['Playlists_id'][i], data1['ChannelID'][i], data1['Playlist_name'][i]) for i in range(len(data1['Playlists_id']))]
#       2 insert_query = f"INSERT INTO {table_name} (Playlists_id, ChannelID, Playlist_name) VALUES (%s, %s, %s);"
#       3 insert_query
#
# KeyError: 'Playlists_id'

# %%
insert_query
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_14068\3795183631.py in <module>
# ----> 1 insert_query
#
# NameError: name 'insert_query' is not defined

# %%
from PIL import Image
import io

im = Image.open("image1.png")

image_bytes = io.BytesIO()
im.save(image_bytes, format='PNG')

dict1 = {
"_id":"nirmalguvi",
'image': image_bytes.getvalue()
}

records.insert_one(dict1)

# %%
#Reading image from Mongo
#from pymongo import MongoClient
from PIL import Image
import io
#import matplotlib.pyplot as plt


retrival = records.find_one({"_id":"nirmalguvi"})
#print(retrival)


pil_img = Image.open(io.BytesIO(retrival['image']))
#plt.imshow(pil_img)
#pil_img.show()
pil_img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGB size=220x165>
